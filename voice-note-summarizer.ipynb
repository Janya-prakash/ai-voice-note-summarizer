# %% [markdown]
# # AI Voice Note Summarizer
#
# This notebook implements a simple AI pipeline that:
#
# 1. Transcribes a short `.wav` voice note into text using speech recognition (Google Web Speech API via the `speech_recognition` library).
# 2. Summarizes the transcribed text into a shorter version using an extractive NLP summarization algorithm (LSA via the `sumy` library).
#
# The goal is to prototype an **AI-based voice note summarizer** that can help quickly review the main points from recorded audio notes.

# %%
# !pip install speechrecognition sumy pydub
# Out:
# Requirement already satisfied: speechrecognition in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.14.5)
# Requirement already satisfied: sumy in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.11.0)
# Requirement already satisfied: pydub in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.25.1)
# Requirement already satisfied: typing-extensions in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from speechrecognition) (4.15.0)
# Requirement already satisfied: standard-aifc in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from speechrecognition) (3.13.0)
# Requirement already satisfied: audioop-lts in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from speechrecognition) (0.2.2)
# Requirement already satisfied: docopt<0.7,>=0.6.1 in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sumy) (0.6.2)
# Requirement already satisfied: breadability>=0.1.20 in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sumy) (0.1.20)
# Requirement already satisfied: requests>=2.7.0 in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sumy) (2.32.5)
# Requirement already satisfied: pycountry>=18.2.23 in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sumy) (24.6.1)
# Requirement already satisfied: nltk>=3.0.2 in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sumy) (3.9.2)
# Requirement already satisfied: chardet in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from breadability>=0.1.20->sumy) (5.2.0)
# Requirement already satisfied: lxml>=2.0 in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from breadability>=0.1.20->sumy) (6.0.2)
# Requirement already satisfied: click in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk>=3.0.2->sumy) (8.3.1)
# Requirement already satisfied: joblib in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk>=3.0.2->sumy) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk>=3.0.2->sumy) (2026.1.15)
# Requirement already satisfied: tqdm in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk>=3.0.2->sumy) (4.67.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.7.0->sumy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.7.0->sumy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.7.0->sumy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.7.0->sumy) (2026.1.4)
# Requirement already satisfied: colorama in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from click->nltk>=3.0.2->sumy) (0.4.6)
# Requirement already satisfied: standard-chunk in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from standard-aifc->speechrecognition) (3.13.0)

# %%
import speech_recognition as sr

from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer  # LSA-based summarizer

# %%
def transcribe_audio(file_path: str) -> str:
    """
    Transcribe a short .wav audio file to text using Google's Web Speech API.
    Returns the transcribed text (string) or an empty string on failure.
    """
    recognizer = sr.Recognizer()

    try:
        with sr.AudioFile(file_path) as source:
            audio_data = recognizer.record(source)  # read the entire file

        # Use Google's free web API
        text = recognizer.recognize_google(audio_data, language="en-IN")  # or "en-US"
        return text

    except sr.UnknownValueError:
        print("Speech Recognition could not understand the audio.")
        return ""
    except sr.RequestError as e:
        print(f"Could not request results from Google Speech Recognition service; {e}")
        return ""

# %%
def summarize_text(text: str, num_sentences: int = 3) -> str:
    """
    Summarize the input text into a shorter version with num_sentences sentences.
    Uses an LSA-based extractive summarizer from sumy.
    """
    if not text.strip():
        return ""

    parser = PlaintextParser.from_string(text, Tokenizer("english"))
    summarizer = LsaSummarizer()

    summary_sentences = summarizer(parser.document, num_sentences)
    summary = " ".join(str(sentence) for sentence in summary_sentences)
    return summary

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.9.2)
# Requirement already satisfied: click in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: tqdm in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in C:\Users\ACER\AppData\Local\Programs\Python\Python314\Lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk

# Download sentence tokenizer data
nltk.download('punkt')
# For newer NLTK versions, also:
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
def summarize_voice_note(audio_path: str, num_sentences: int = 2):
    """
    Convenience function: given a .wav audio file path,
    transcribe it and print both the full transcript and a short summary.
    """
    print(f"Processing audio file: {audio_path}\n")

    transcript = transcribe_audio(audio_path)
    print("=== Full Transcript ===")
    print(transcript)

    summary = summarize_text(transcript, num_sentences=num_sentences)
    print(f"\n=== Summary ({num_sentences} sentences) ===")
    print(summary)

    return transcript, summary

# %%
transcript, summary = summarize_voice_note("my_note.wav", num_sentences=2)
# Out:
# Processing audio file: my_note.wav
#
# === Full Transcript ===
# today I want to talk about why I started using voice notes to organise my day typing long messages or detailed to do list on my phone can sometimes feel slow and tiring especially when I have a lot of thoughts at once with voice notes I can quickly capture ideas about assignments project deadlines and personal reminders without worrying about spelling or formatting however the problem is that this was not pilot and become hard to review I often don't have time to listen to every recording from start to finish that is why having an AI based was not summarizer could be really helpful it would allow me to record my thoughts naturally convert this page into text and then generate a short clear summary this way I could quickly understand the main points of each node and stay organised without spending extra time
#
# === Summary (2 sentences) ===
# today I want to talk about why I started using voice notes to organise my day typing long messages or detailed to do list on my phone can sometimes feel slow and tiring especially when I have a lot of thoughts at once with voice notes I can quickly capture ideas about assignments project deadlines and personal reminders without worrying about spelling or formatting however the problem is that this was not pilot and become hard to review I often don't have time to listen to every recording from start to finish that is why having an AI based was not summarizer could be really helpful it would allow me to record my thoughts naturally convert this page into text and then generate a short clear summary this way I could quickly understand the main points of each node and stay organised without spending extra time

# %%
transcript2, summary2 = summarize_voice_note("note2.wav", num_sentences=2)
# Out:
# Processing audio file: note2.wav
#
# === Full Transcript ===
# I have been trying to improve the way I study for exams especially when I have multiple subjects like mathematics statistics and programming at the same time in the past I used to read just my notes passively and hope I would remember everything but that often left me confused right before the exam now I am experimenting with the more structured routine first I break topics into smaller parts and create a simple daily plan so that I do not get overwhelmed second I try to explain key concepts in my own words either by speaking them out loud or teaching them to a friend finally I review important formulas and theorems with quick revision sheets a few days before the test I think this new approach is helping mistake more organised and confident but I still need to be consistent and a while distractions from my phone and social media
#
# === Summary (2 sentences) ===
# I have been trying to improve the way I study for exams especially when I have multiple subjects like mathematics statistics and programming at the same time in the past I used to read just my notes passively and hope I would remember everything but that often left me confused right before the exam now I am experimenting with the more structured routine first I break topics into smaller parts and create a simple daily plan so that I do not get overwhelmed second I try to explain key concepts in my own words either by speaking them out loud or teaching them to a friend finally I review important formulas and theorems with quick revision sheets a few days before the test I think this new approach is helping mistake more organised and confident but I still need to be consistent and a while distractions from my phone and social media
